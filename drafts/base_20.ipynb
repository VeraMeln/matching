# %%
import faiss
import pandas as pd
import datetime as dt
import numpy as np
from tqdm.notebook import tqdm

from catboost import CatBoostClassifier

# %%
path = r"C:\Users\Admin\Documents\УЧЕБА\20 мастерская 2\notebooks\datasets\base_2.0.csv"

# %%
start_time = dt.datetime.now().timestamp()
base_2_0 = pd.read_csv(path, index_col=0)
dt.datetime.now().timestamp() - start_time
# Out:
# 42.978703022003174

# %%
base_2_0.head(2)
# Out:
#                   0          1          2          3           4          5  \
# Id
# 1-base   -34.562202  13.332763  -69.78761 -166.53348   57.680607 -86.098370
# 15-base -133.391540   4.454095 -127.94336 -123.74695  143.213870 -38.265465
#
#                   6          7           8           9  ...         63  \
# Id                                                      ...
# 1-base   -85.076666 -35.637436  119.718636  195.234190  ...  41.100000
# 15-base -224.939111 -84.442410  127.770160   50.926636  ...  54.980003
#
#                 64          65        66         67         68         69  \
# Id
# 1-base  -157.82940  -94.446806  68.20211  24.346846  179.93793  116.83400
# 15-base -242.59491  103.561070  70.54476 -54.223568  142.79533   93.46864
#
#                   70          71  class
# Id
# 1-base    -84.888941  -59.524610    2.0
# 15-base -1074.464888 -108.886154    2.0
#
# [2 rows x 73 columns]

# %% [markdown]
# ### Create index

# %%
start_time = dt.datetime.now().timestamp()

dims = base_2_0.shape[1]
n_cells = round(base_2_0.shape[1] ** 0.5)
# how many cells
quantizer = faiss.IndexFlatL2(dims)
idx_l2 = faiss.IndexIVFFlat(quantizer, dims, n_cells)

dt.datetime.now().timestamp() - start_time
# Out:
# 0.21276116371154785

# %%
start_time = dt.datetime.now().timestamp()

idx_l2.train(np.ascontiguousarray(base_2_0.values).astype('float32'))

idx_l2.add(np.ascontiguousarray(base_2_0.values).astype('float32'))
dt.datetime.now().timestamp() - start_time
# Out:
# 27.277456998825073

# %%
base_index = {k: v for k, v in enumerate(base_2_0.index.to_list())}
len(base_index)
# Out:
# 632110

# %% [markdown]
# # Train

# %%
df_train = pd.read_csv("datasets/train_2.0.csv", index_col=0)

# %%
targets = df_train["Target"]
df_train.drop("Target", axis=1, inplace=True)

# %%
idx_l2.nprobe = 20

# %% [markdown]
# ## idx_l2

# %%
start_time = dt.datetime.now().timestamp()
vecs, idx = idx_l2.search(np.ascontiguousarray(df_train.values).astype('float32'), 100)
time_spent = dt.datetime.now().timestamp() - start_time
time_spent, time_spent // 60, time_spent % 60
# Out:
# (286.87781405448914, 4.0, 46.877814054489136)

# %%
acc = 0
for target, el in zip(targets.values.tolist(), idx.tolist()):
    acc += int(target in [base_index[r] for r in el])

print(100 * acc / len(idx))
# Out:
# 5.8353925109294815

# %%
df_train.head()
# Out:
#                   0          1          2          3          4          5  \
# Id
# 0-query  -53.882748  17.971436 -42.117104 -183.93668  187.51749 -87.144930
# 1-query  -87.776370   6.806268 -32.054546 -177.26039  120.80333 -83.810590
# 5-query  -92.844185   2.975510 -61.760483 -171.67546  144.79837 -58.685143
# 7-query  -59.506752   7.959120  21.068153 -142.99788  128.15799 -92.496300
# 10-query -80.497215   4.198283  22.420013 -135.29889  119.97193 -81.749275
#
#                    6           7          8           9  ...         63  \
# Id                                                       ...
# 0-query  -347.360606   38.307602  109.08556   30.413513  ...  70.107360
# 1-query   -94.572749  -78.433090  124.91590  140.331070  ...   4.669178
# 5-query   104.112909   75.844580  118.33623   81.981125  ...  12.807585
# 7-query  -143.453758   10.710561  131.08679   71.491560  ...  49.263610
# 10-query -530.124724  117.829230  128.16780  129.974720  ...  41.703710
#
#                  64          65         66         67         68         69  \
# Id
# 0-query  -155.80257 -101.965943  65.903790  34.457500  62.642094  134.76360
# 1-query  -151.69771   -1.638704  68.170876  25.096191  89.974976  130.58963
# 5-query  -137.96362   86.282088  64.678535  64.527600  64.664440  126.91460
# 7-query  -203.78833 -101.989379  67.291770  44.437595  45.183838  150.28853
# 10-query -192.11499  149.374627  67.501175  32.233040  86.700900  121.77761
#
#                    70         71  class
# Id
# 0-query   -415.750254 -25.958572    2.0
# 1-query  -1035.092211 -51.276833    2.0
# 5-query   -800.428664 -30.197390    2.0
# 7-query  -1074.464888 -66.052086    2.0
# 10-query  -640.529192 -60.236816    2.0
#
# [5 rows x 73 columns]

# %%
targets.shape, targets.nunique()
# Out:
# ((15783,), 15503)

# %% [markdown]
# ## CatBoostClassifier

# %%
features = df_train.drop("class", axis=1)
features.head()
# Out:
#                   0          1          2          3          4          5  \
# Id
# 0-query  -53.882748  17.971436 -42.117104 -183.93668  187.51749 -87.144930
# 1-query  -87.776370   6.806268 -32.054546 -177.26039  120.80333 -83.810590
# 5-query  -92.844185   2.975510 -61.760483 -171.67546  144.79837 -58.685143
# 7-query  -59.506752   7.959120  21.068153 -142.99788  128.15799 -92.496300
# 10-query -80.497215   4.198283  22.420013 -135.29889  119.97193 -81.749275
#
#                    6           7          8           9  ...          62  \
# Id                                                       ...
# 0-query  -347.360606   38.307602  109.08556   30.413513  ... -105.427820
# 1-query   -94.572749  -78.433090  124.91590  140.331070  ...  -40.812233
# 5-query   104.112909   75.844580  118.33623   81.981125  ...  -72.797980
# 7-query  -143.453758   10.710561  131.08679   71.491560  ...  -65.693565
# 10-query -530.124724  117.829230  128.16780  129.974720  ...  -91.857834
#
#                  63         64          65         66         67         68  \
# Id
# 0-query   70.107360 -155.80257 -101.965943  65.903790  34.457500  62.642094
# 1-query    4.669178 -151.69771   -1.638704  68.170876  25.096191  89.974976
# 5-query   12.807585 -137.96362   86.282088  64.678535  64.527600  64.664440
# 7-query   49.263610 -203.78833 -101.989379  67.291770  44.437595  45.183838
# 10-query  41.703710 -192.11499  149.374627  67.501175  32.233040  86.700900
#
#                  69           70         71
# Id
# 0-query   134.76360  -415.750254 -25.958572
# 1-query   130.58963 -1035.092211 -51.276833
# 5-query   126.91460  -800.428664 -30.197390
# 7-query   150.28853 -1074.464888 -66.052086
# 10-query  121.77761  -640.529192 -60.236816
#
# [5 rows x 72 columns]

# %%
cbc = CatBoostClassifier()

# %%
start_time = dt.datetime.now().timestamp()
cbc.fit(features, targets)
dt.datetime.now().timestamp() - start_time
time_spent, time_spent // 60, time_spent % 60
# Out:
# Learning rate set to 0.091082
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[25], line 2
#       1 start_time = dt.datetime.now().timestamp()
# ----> 2 cbc.fit(features, targets)
#       3 dt.datetime.now().timestamp() - start_time
#       4 time_spent, time_spent // 60, time_spent % 60
#
# File ~\anaconda3\Lib\site-packages\catboost\core.py:5131, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5128 if 'loss_function' in params:
#    5129     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5131 self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5132           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5133           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5134 return self
#
# File ~\anaconda3\Lib\site-packages\catboost\core.py:2357, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2353 allow_clear_pool = train_params["allow_clear_pool"]
#    2355 with log_fixup(log_cout, log_cerr), \
#    2356     plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2357     self._train(
#    2358         train_pool,
#    2359         train_params["eval_sets"],
#    2360         params,
#    2361         allow_clear_pool,
#    2362         train_params["init_model"]
#    2363     )
#    2365 # Have property feature_importance possibly set
#    2366 loss = self._object._get_loss_function_name()
#
# File ~\anaconda3\Lib\site-packages\catboost\core.py:1761, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1760 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1761     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1762     self._set_trained_model_attributes()
#
# File _catboost.pyx:4624, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4673, in _catboost._CatBoost._train()
#
# CatBoostError: bad allocation
