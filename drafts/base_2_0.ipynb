# %%
import faiss
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import faiss
#
# ModuleNotFoundError: No module named 'faiss'

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %%
# %%time
base_2 = pd.read_csv('datasets/base_2.0.csv')
# Out:
# CPU times: total: 4.23 s
# Wall time: 4.24 s

# %%
base_2.hist(figsize=(15, 30));

# %% [markdown]
# Характер распределения значений столбца 33 не изменился, но диапазон значений сократился. Остальные характеристики не изменились.

# %%
base_2['33'].min(), base_2['33'].max()
# Out:
# (-362.98512080354766, -181.5984765532835)
